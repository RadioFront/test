# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import time, sys
from pymavlink import mavutil
import threading
import math

#import base64
#import imageio
#import IPython
#import matplotlib.pyplot as plt
import numpy as np
import os
#import PIL.Image
#import pyvirtualdisplay
import reverb

import tensorflow as tf

from tf_agents.agents.reinforce import reinforce_agent
from tf_agents.drivers import py_driver
from tf_agents.networks import actor_distribution_network
from tf_agents.policies import py_tf_eager_policy
from tf_agents.policies import policy_saver
from tf_agents.policies import random_tf_policy
from tf_agents.replay_buffers import reverb_replay_buffer
from tf_agents.replay_buffers import reverb_utils
from tf_agents.specs import tensor_spec
from tf_agents.specs import array_spec
from tf_agents.trajectories import trajectory
from tf_agents.trajectories import time_step as ts
from tf_agents.utils import common
from tf_agents.environments import py_environment
from tf_agents.environments import tf_environment
from tf_agents.environments import tf_py_environment
from tf_agents.environments import utils
from tf_agents.environments import wrappers
from tf_agents.environments import suite_gym

# %%
#####################
# parameters
target_elevation = 50
period_action = 0.1
period_telemetry = 0.1
frequency_message = 10
period_set_position = 1/5
time_arm_mode = 1
time_settling = 10
stamp_state = time.time()
stamp_telemetry = time.time()
stamp_set_position = time.time()
period_delay = 0.01
time_steady_state = 1
#no_sample=1200
sample_period = 0.1
mode = "none"
state = "arm"
stampState=time.time()
stampMode=time.time()
vec_telemetry=[]
vec_pid_update=[]
#####################
# drone controller parameters
## Rate Controller
MC_ROLLRATE_K = 1.0 #0.3 - 3
MC_ROLLRATE_D = 0.003 #0.0004 - 0.01
MC_ROLLRATE_I = 0.2 #0.1 - 0.5
MC_PITCHRATE_K = 1.0 #0.3 - 3
MC_PITCHRATE_D = 0.003 #0.0004 - 0.01
MC_PITCHRATE_I = 0.2 #0.1 - 0.5
MC_YAWRATE_K = 1.0 #0.3 - 3
MC_YAWRATE_I = 0.1 #0.04 - 0.4
## Attitude Controller
MC_ROLL_P = 6.5 #1-14
MC_PITCH_P = 6.5 #1-14
MC_YAW_P = 2.8 #1-5
## Velocity Controller
MPC_XY_VEL_P_ACC = 1.8 #1.2-5
MPC_XY_VEL_I_ACC = 0.2 #0.2-10
MPC_XY_VEL_D_ACC = 0.2 #0.1-2
MPC_Z_VEL_P_ACC = 4.0 #2-15
MPC_Z_VEL_I_ACC = 2.0 #0.2-3
MPC_Z_VEL_D_ACC = 0.0 #0-2
## Position Controller
MPC_XY_P = 0.95 #0-2
MPC_Z_P = 1.0 #0-2

# %%
def px4_arm():
    # Arm motors
    state = "arm"
    print("State:",state)
    master.mav.command_long_send(
        master.target_system, master.target_component,
        mavutil.mavlink.MAV_CMD_COMPONENT_ARM_DISARM,
        0,
        1, 0, 0, 0, 0, 0, 0)
    master.motors_armed_wait()
    state = "set_mode"
    print("State:",state)
    stampState = time.time()
    stampMode = time.time()

def px4_steady_state():
    ##### Put down at steady state
    mode = "none"
    state = "set_mode"
    stampState = time.time()
    stamp_set_position = time.time()
    while mode!="steady_state":
        # set OFFBOARD mode
        if state == "set_mode" and ( time.time() - stampState > time_arm_mode ):
            master.mav.command_long_send(
                master.target_system,
                master.target_component,
                mavutil.mavlink.MAV_CMD_DO_SET_MODE,
                0,
                209, 6, 0, 0, 0, 0, 0) #OFFBOARD mode
            state = "mode_wait"
            print("State:",state)
            stampState = time.time()

        #wait fof OFFBOARD mode acknowledged
        if state == "mode_wait" and ( time.time() - stampState > time_arm_mode):
            ack_msg = master.recv_match(type='COMMAND_ACK')
            if ack_msg:
                ack_msg = ack_msg.to_dict()
                if ack_msg['command'] == mavutil.mavlink.MAV_CMD_DO_SET_MODE:
                    print(mavutil.mavlink.enums['MAV_RESULT'][ack_msg['result']].description)
                    state = "ramp_up"
                    stampState = time.time()
                    print("State:",state)
                    
        # wait till the drone reaches target position
        if state == "ramp_up" and ( time.time() - stampState > time_settling):
            state = "flight_mode"
            print("State:",state)
            stampState = time.time()

        # repeat position setup > 2 Hz, to avoid fail safe mode kick in
        if time.time() - stamp_set_position > period_set_position:
            stamp_set_position = time.time()
            px4_set_target_depth_local(-target_elevation)

        # unit delay
        time.sleep(delay_unit)

        t_param='POSITION_TARGET_LOCAL_NED' #85
        try: 
            POSITION_TARGET_LOCAL_NED_x= master.messages[t_param].x
            #POSITION_TARGET_LOCAL_NED_y= master.messages[t_param].y
            #POSITION_TARGET_LOCAL_NED_z= master.messages[t_param].z
            #print(t_param, ":", POSITION_TARGET_LOCAL_NED_x,POSITION_TARGET_LOCAL_NED_y,POSITION_TARGET_LOCAL_NED_z)
            if mode == "none" and math.isnan(POSITION_TARGET_LOCAL_NED_x) == False:
                mode = "flight_mode"
                stampMode = time.time()
                print("Mode:",mode)
        except:
            print(t_param,":",'No message received')

        t_param='LOCAL_POSITION_NED' #32
        try: 
            LOCAL_POSITION_NED_x = master.messages[t_param].x
            LOCAL_POSITION_NED_y = master.messages[t_param].y
            LOCAL_POSITION_NED_z = master.messages[t_param].z
            #print(t_param, ":", LOCAL_POSITION_NED_x, LOCAL_POSITION_NED_y, LOCAL_POSITION_NED_z)
            if mode == "flight_mode" and distance_target([LOCAL_POSITION_NED_x, LOCAL_POSITION_NED_y, LOCAL_POSITION_NED_z])<0.3:
                mode = "steady_state"
                stampMode = time.time()
                print("Mode:",mode)
        except:
            print(t_param, ":", 'No message received')

def distance_geo(A,B):
    return math.sqrt( (A[0]-B[0])**2 + (A[1]-B[1])**2 + (A[2]-B[2])**2 )

def distance_target(A):
    return math.sqrt( A[0]**2 + A[1]**2 + (A[2]+target_elevation)**2 )

def px4_request_message_interval(message_id: int, frequency_hz: float):
    master.mav.command_long_send(
        master.target_system, master.target_component,
        mavutil.mavlink.MAV_CMD_SET_MESSAGE_INTERVAL, 0,
        message_id, # The MAVLink message ID
        1e6 / frequency_hz, # The interval between two messages in microseconds. Set to -1 to disable and 0 to request default rate.
        0, 0, 0, 0, # Unused parameters
        0, # Target address of message stream (if message has target address fields). 0: Flight-stack default (recommended), 1: address of requestor, 2: broadcast.
    )

def px4_set_target_depth_local(depth):
    master.mav.set_position_target_local_ned_send( #84
        int(1e3 * (time.time() - boot_time)), # ms since boot
        master.target_system, master.target_component,
        coordinate_frame=mavutil.mavlink.MAV_FRAME_LOCAL_NED,
        type_mask=( # ignore everything except z position
            # mavutil.mavlink.POSITION_TARGET_TYPEMASK_X_IGNORE |
            # mavutil.mavlink.POSITION_TARGET_TYPEMASK_Y_IGNORE |
            # mavutil.mavlink.POSITION_TARGET_TYPEMASK_Z_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_VX_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_VY_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_VZ_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_AX_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_AY_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_AZ_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_FORCE_SET |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_YAW_IGNORE |
            mavutil.mavlink.POSITION_TARGET_TYPEMASK_YAW_RATE_IGNORE
        ), x=0, y=0, z=depth,
        vx=0, vy=0, vz=0, 
        afx=0, afy=0, afz=0, yaw=0, yaw_rate=0
    )

def px4_request_message():
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_SYS_STATUS, frequency_message) #1
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_SET_MODE, frequency_message) #1
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_GPS_RAW_INT, frequency_message) #24
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_SCALED_IMU, frequency_message) #26
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_ATTITUDE, frequency_message) #30
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_ATTITUDE_QUATERNION, frequency_message) #31
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_LOCAL_POSITION_NED, frequency_message) #32
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_GLOBAL_POSITION_INT, frequency_message) #33
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_SERVO_OUTPUT_RAW, frequency_message) #36
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_VFR_HUD, frequency_message) #74
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_ATTITUDE_TARGET, frequency_message) #83
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_POSITION_TARGET_LOCAL_NED, frequency_message) #85
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_POSITION_TARGET_GLOBAL_INT, frequency_message) #87
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_ALTITUDE, frequency_message) #141
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_BATTERY_STATUS, frequency_message) #147
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_ESTIMATOR_STATUS, frequency_message) #230
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_VIBRATION, frequency_message) #241
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_UTM_GLOBAL_POSITION, frequency_message) #340
    px4_request_message_interval(mavutil.mavlink.MAVLINK_MSG_ID_OPEN_DRONE_ID_LOCATION, frequency_message) #12901

# %%
def px4_reset_pid_controller():
    #####################
    # drone controller parameters
    ## Rate Controller
    MC_ROLLRATE_K = 1.0 #0.3 - 3
    MC_ROLLRATE_D = 0.003 #0.0004 - 0.01
    MC_ROLLRATE_I = 0.2 #0.1 - 0.5
    MC_PITCHRATE_K = 1.0 #0.3 - 3
    MC_PITCHRATE_D = 0.003 #0.0004 - 0.01
    MC_PITCHRATE_I = 0.2 #0.1 - 0.5
    MC_YAWRATE_K = 1.0 #0.3 - 3
    MC_YAWRATE_I = 0.1 #0.04 - 0.4
    ## Attitude Controller
    MC_ROLL_P = 6.5 #1-14
    MC_PITCH_P = 6.5 #1-14
    MC_YAW_P = 2.8 #1-5
    ## Velocity Controller
    MPC_XY_VEL_P_ACC = 1.8 #1.2-5
    MPC_XY_VEL_I_ACC = 0.2 #0.2-10
    MPC_XY_VEL_D_ACC = 0.2 #0.1-2
    MPC_Z_VEL_P_ACC = 4.0 #2-15
    MPC_Z_VEL_I_ACC = 2.0 #0.2-3
    MPC_Z_VEL_D_ACC = 0.0 #0-2
    ## Position Controller
    MPC_XY_P = 0.95 #0-2
    MPC_Z_P = 1.0 #0-2
    #####################
    ## Rate Controller
    #PITCH
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_K', MC_PITCHRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_D', MC_PITCHRATE_D, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_I', MC_PITCHRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #ROLL
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_K', MC_ROLLRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_D', MC_ROLLRATE_D, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_I', MC_ROLLRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #YAW
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAWRATE_K', MC_YAWRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAWRATE_I', MC_YAWRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Attitude Controller
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLL_P', MC_ROLL_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCH_P', MC_PITCH_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAW_P', MC_YAW_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Velocity Controller
    #XY
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_P_ACC', MPC_XY_VEL_P_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_I_ACC', MPC_XY_VEL_I_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_D_ACC', MPC_XY_VEL_D_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #Z
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_P_ACC', MPC_Z_VEL_P_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_I_ACC', MPC_Z_VEL_I_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_D_ACC', MPC_Z_VEL_D_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Position Controller
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_P', MPC_XY_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_P', MPC_Z_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)

def px4_update_pid_controller_rate_att(action):
    ## Rate Controller
    MC_PITCHRATE_K=action[0]
    MC_PITCHRATE_D=action[1]
    MC_PITCHRATE_I=action[2]
    MC_ROLLRATE_K=action[3]
    MC_ROLLRATE_D=action[4]
    MC_ROLLRATE_I=action[5]
    MC_YAWRATE_K=action[6]
    MC_YAWRATE_I=action[7]
    #PITCH
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_K', MC_PITCHRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_D', MC_PITCHRATE_D, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_I', MC_PITCHRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #ROLL
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_K', MC_ROLLRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_D', MC_ROLLRATE_D, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_I', MC_ROLLRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #YAW
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAWRATE_K', MC_YAWRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAWRATE_I', MC_YAWRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)

def px4_update_pid_controller_velocity_pos(action):
    ## Velocity Controller
    MPC_XY_VEL_P_ACC = action[0] #1.8 #1.2-5
    MPC_XY_VEL_I_ACC = action[1] #0.2 #0.2-10
    MPC_XY_VEL_D_ACC = action[2] #0.2 #0.1-2
    MPC_Z_VEL_P_ACC = action[3] #4.0 #2-15
    MPC_Z_VEL_I_ACC = action[4] #2.0 #0.2-3
    MPC_Z_VEL_D_ACC = action[5] #0.0 #0-2
    ## Position Controller
    MPC_XY_P = action[6] #0.95 #0-2
    MPC_Z_P = action[7] #1.0 #0-2
    ## Velocity Controller
    #XY
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_P_ACC', MPC_XY_VEL_P_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_I_ACC', MPC_XY_VEL_I_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_D_ACC', MPC_XY_VEL_D_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #Z
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_P_ACC', MPC_Z_VEL_P_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_I_ACC', MPC_Z_VEL_I_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_D_ACC', MPC_Z_VEL_D_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Position Controller
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_P', MPC_XY_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_P', MPC_Z_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)

def px4_update_pid_controller_all(action):
    ## Rate Controller
    MC_PITCHRATE_K=action[0]
    MC_PITCHRATE_D=action[1]
    MC_PITCHRATE_I=action[2]
    MC_ROLLRATE_K=action[3]
    MC_ROLLRATE_D=action[4]
    MC_ROLLRATE_I=action[5]
    MC_YAWRATE_K=action[6]
    MC_YAWRATE_I=action[7]
    ## Attitude Controller
    MC_ROLL_P = action[8] #6.5 #1-14
    MC_PITCH_P = action[9] #6.5 #1-14
    MC_YAW_P = action[10] #2.8 #1-5    ## Velocity Controller
    MPC_XY_VEL_P_ACC = action[11] #1.8 #1.2-5
    MPC_XY_VEL_I_ACC = action[12] #0.2 #0.2-10
    MPC_XY_VEL_D_ACC = action[13] #0.2 #0.1-2
    MPC_Z_VEL_P_ACC = action[14] #4.0 #2-15
    MPC_Z_VEL_I_ACC = action[15] #2.0 #0.2-3
    MPC_Z_VEL_D_ACC = action[16] #0.0 #0-2
    ## Position Controller
    MPC_XY_P = action[17] #0.95 #0-2
    MPC_Z_P = action[18] #1.0 #0-2
    #PITCH
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_K', MC_PITCHRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_D', MC_PITCHRATE_D, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCHRATE_I', MC_PITCHRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #ROLL
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_K', MC_ROLLRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_D', MC_ROLLRATE_D, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLLRATE_I', MC_ROLLRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #YAW
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAWRATE_K', MC_YAWRATE_K, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAWRATE_I', MC_YAWRATE_I, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Attitude Controller
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_ROLL_P', MC_ROLL_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_PITCH_P', MC_PITCH_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MC_YAW_P', MC_YAW_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Velocity Controller
    #XY
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_P_ACC', MPC_XY_VEL_P_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_I_ACC', MPC_XY_VEL_I_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_VEL_D_ACC', MPC_XY_VEL_D_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    #Z
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_P_ACC', MPC_Z_VEL_P_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_I_ACC', MPC_Z_VEL_I_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_VEL_D_ACC', MPC_Z_VEL_D_ACC, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    ## Position Controller
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_XY_P', MPC_XY_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)
    master.mav.param_set_send(master.target_system, master.target_component, b'MPC_Z_P', MPC_Z_P, mavutil.mavlink.MAV_PARAM_TYPE_REAL32)

# %%
def px4_get_telemetry_data():
    ack_msg = master.recv_match(type='COMMAND_ACK')
    observation=[]
    t_param='SCALED_IMU' #26
    try: 
        SCALED_IMU_xacc = master.messages[t_param].xacc
        SCALED_IMU_yacc = master.messages[t_param].yacc
        SCALED_IMU_zacc = master.messages[t_param].zacc
        SCALED_IMU_xgyro = master.messages[t_param].xgyro
        SCALED_IMU_ygyro = master.messages[t_param].ygyro
        SCALED_IMU_zgyro = master.messages[t_param].zgyro
        SCALED_IMU_data=[SCALED_IMU_xacc/16384,SCALED_IMU_yacc/16384,SCALED_IMU_zacc/16384,SCALED_IMU_xgyro/16384,SCALED_IMU_ygyro/16384,SCALED_IMU_zgyro/16384]
        observation.extend(SCALED_IMU_data) #count=6
    except:
        print(t_param, ":", 'No message received')

    t_param='ATTITUDE' #30
    try: 
        ATTITUDE_roll = master.messages[t_param].roll
        ATTITUDE_pitch = master.messages[t_param].pitch
        ATTITUDE_yaw = master.messages[t_param].yaw
        ATTITUDE_rollspeed = master.messages[t_param].rollspeed
        ATTITUDE_pitchspeed = master.messages[t_param].pitchspeed
        ATTITUDE_yawspeed = master.messages[t_param].yawspeed
        ATTITUDE_data=[ATTITUDE_roll/2,ATTITUDE_pitch/2,ATTITUDE_yaw/2,ATTITUDE_rollspeed/5,ATTITUDE_pitchspeed/5,ATTITUDE_yawspeed/5]
        observation.extend(ATTITUDE_data) #count=6+6=12
    except:
        print(t_param, ":", 'No message received') #6

    t_param='ATTITUDE_QUATERNION' #31
    try: 
        ATTITUDE_QUATERNION_q1 = master.messages[t_param].q1
        ATTITUDE_QUATERNION_q2 = master.messages[t_param].q2
        ATTITUDE_QUATERNION_q3 = master.messages[t_param].q3
        ATTITUDE_QUATERNION_q4 = master.messages[t_param].q4
        ATTITUDE_QUATERNION_rollspeed = master.messages[t_param].rollspeed
        ATTITUDE_QUATERNION_pitchspeed = master.messages[t_param].pitchspeed
        ATTITUDE_QUATERNION_yawspeed = master.messages[t_param].yawspeed
        ATTITUDE_QUATERNION_data=[ATTITUDE_QUATERNION_q1,ATTITUDE_QUATERNION_q2,ATTITUDE_QUATERNION_q3,ATTITUDE_QUATERNION_q4,ATTITUDE_QUATERNION_rollspeed/5,ATTITUDE_QUATERNION_pitchspeed/5,ATTITUDE_QUATERNION_yawspeed/5]
        observation.extend(ATTITUDE_QUATERNION_data) #count=12+7=19
    except:
        print(t_param, ":", 'No message received')

    t_param='LOCAL_POSITION_NED' #32
    try: 
        LOCAL_POSITION_NED_x = master.messages[t_param].x
        LOCAL_POSITION_NED_y = master.messages[t_param].y
        LOCAL_POSITION_NED_z = master.messages[t_param].z + 10
        LOCAL_POSITION_NED_vx = master.messages[t_param].vx
        LOCAL_POSITION_NED_vy = master.messages[t_param].vy
        LOCAL_POSITION_NED_vz = master.messages[t_param].vz
        LOCAL_POSITION_NED_data=[LOCAL_POSITION_NED_x/10,LOCAL_POSITION_NED_y/10,(LOCAL_POSITION_NED_z+target_elevation)/10,LOCAL_POSITION_NED_vx/10,LOCAL_POSITION_NED_vy/10,LOCAL_POSITION_NED_vz/10]
        observation.extend(LOCAL_POSITION_NED_data) #count=19+6=25
    except:
        print(t_param, ":", 'No message received')

    t_param='SERVO_OUTPUT_RAW' #36
    try: 
        SERVO_OUTPUT_RAW_servo1_raw = master.messages[t_param].servo1_raw - 1500
        SERVO_OUTPUT_RAW_servo2_raw = master.messages[t_param].servo2_raw - 1500
        SERVO_OUTPUT_RAW_servo3_raw = master.messages[t_param].servo3_raw - 1500
        SERVO_OUTPUT_RAW_servo4_raw = master.messages[t_param].servo4_raw - 1500
        SERVO_OUTPUT_RAW_data=[SERVO_OUTPUT_RAW_servo1_raw/500,SERVO_OUTPUT_RAW_servo2_raw/500,SERVO_OUTPUT_RAW_servo3_raw/500,SERVO_OUTPUT_RAW_servo4_raw/500]
        observation.extend(SERVO_OUTPUT_RAW_data) #count=25+4=29
    except:
        print(t_param, ":", 'No message received')

    t_param='VFR_HUD' #74
    try: 
        #VFR_HUD_airspeed = master.messages[t_param].airspeed
        VFR_HUD_groundspeed = master.messages[t_param].groundspeed
        VFR_HUD_heading = master.messages[t_param].heading
        VFR_HUD_throttle = master.messages[t_param].throttle
        #VFR_HUD_alt = master.messages[t_param].alt
        VFR_HUD_climb = master.messages[t_param].climb
        VFR_HUD_data=[VFR_HUD_groundspeed/10,VFR_HUD_heading/360,VFR_HUD_throttle/100,VFR_HUD_climb/10]
        observation.extend(VFR_HUD_data) #count=29+4=33
    except:
        print(t_param, ":", 'No message received')
        
    t_param='ATTITUDE_TARGET' #83
    try: 
        ATTITUDE_TARGET_q = master.messages[t_param].q
        ATTITUDE_TARGET_body_roll_rate = master.messages[t_param].body_roll_rate
        ATTITUDE_TARGET_body_pitch_rate = master.messages[t_param].body_pitch_rate
        ATTITUDE_TARGET_body_yaw_rate = master.messages[t_param].body_yaw_rate
        ATTITUDE_TARGET_thrust = master.messages[t_param].thrust
        ATTITUDE_TARGET_data=[ATTITUDE_TARGET_q[0],ATTITUDE_TARGET_q[1],ATTITUDE_TARGET_q[2],ATTITUDE_TARGET_q[3],ATTITUDE_TARGET_body_roll_rate/4,ATTITUDE_TARGET_body_pitch_rate/4,ATTITUDE_TARGET_body_yaw_rate/4,ATTITUDE_TARGET_thrust]
        observation.extend(ATTITUDE_TARGET_data) #count=33+8=41
    except:
        print(t_param, ":", 'No message received')

    t_param='ESTIMATOR_STATUS' #230
    try: 
        ESTIMATOR_STATUS_vel_ratio = master.messages[t_param].vel_ratio
        ESTIMATOR_STATUS_pos_horiz_ratio = master.messages[t_param].pos_horiz_ratio
        ESTIMATOR_STATUS_pos_vert_ratio = master.messages[t_param].pos_vert_ratio
        ESTIMATOR_STATUS_mag_ratio = master.messages[t_param].mag_ratio
        ESTIMATOR_STATUS_data=[ESTIMATOR_STATUS_vel_ratio/5,ESTIMATOR_STATUS_pos_horiz_ratio,ESTIMATOR_STATUS_pos_vert_ratio,ESTIMATOR_STATUS_mag_ratio]
        observation.extend(ESTIMATOR_STATUS_data) #count=41+4=45
    except:
        print(t_param, ":", 'No message received')

    t_param='UTM_GLOBAL_POSITION' #340
    try: 
        UTM_GLOBAL_POSITION_vx = master.messages[t_param].vx
        UTM_GLOBAL_POSITION_vy = master.messages[t_param].vy
        UTM_GLOBAL_POSITION_vz = master.messages[t_param].vz
        UTM_GLOBAL_POSITION_data=[UTM_GLOBAL_POSITION_vx/1000, UTM_GLOBAL_POSITION_vy/1000, UTM_GLOBAL_POSITION_vz/1000]
        observation.extend(UTM_GLOBAL_POSITION_data) #count=45+3=48
    except:
        print(t_param, ":", 'No message received')

    t_param='OPEN_DRONE_ID_LOCATION' #12901
    try: 
        OPEN_DRONE_ID_LOCATION_speed_horizontal = master.messages[t_param].speed_horizontal
        OPEN_DRONE_ID_LOCATION_speed_vertical = master.messages[t_param].speed_vertical
        OPEN_DRONE_ID_LOCATION_data=[OPEN_DRONE_ID_LOCATION_speed_horizontal/1000, OPEN_DRONE_ID_LOCATION_speed_vertical/1000]
        observation.extend(OPEN_DRONE_ID_LOCATION_data) #count=48+2=50
    except:
        print(t_param, ":", 'No message received')

    return observation

def px4_get_position_data():
    ack_msg = master.recv_match(type='COMMAND_ACK')
    t_param='LOCAL_POSITION_NED' #32
    try: 
        LOCAL_POSITION_NED_x = master.messages[t_param].x
        LOCAL_POSITION_NED_y = master.messages[t_param].y
        LOCAL_POSITION_NED_z = master.messages[t_param].z
        return [LOCAL_POSITION_NED_x, LOCAL_POSITION_NED_y, LOCAL_POSITION_NED_z]
    except:
        print(t_param, ":", 'No message received')
        return [0,0,0]

# %%
class PX4_RL_PID(py_environment.PyEnvironment):
    def __init__(self, noSample, delay_period, action_period):
        self.sample_size = noSample
        self.delay_period = delay_period
        self.action_period = action_period
        self.noObs = 50
        self.sample_stamp = 0
        self.track_distance = 0
        self.max_distance = 0
        self.action_history = []
        self.observation_history = []
        self.reward_accumulate = 0
        tActionMin=[0.3, 0.0004, 0.1, 0.3, 0.0004, 0.1, 0.3, 0.04,  1.0,  1.0, 1.0, 1.2,  0.2, 0.1,  2.0, 0.2, 0.0, 0.0, 0.0]
        tActionMax=[3.0,   0.01, 0.5, 3.0,   0.01, 0.5, 3.0,  0.4, 14.0, 14.0, 5.0, 5.0, 10.0, 2.0, 15.0, 3.0, 2.0, 2.0, 2.0]
        tObsMin=[-1.0] * self.noObs
        tObsMax=[ 1.0] * self.noObs
        self._action_spec = array_spec.BoundedArraySpec(
            shape=(19,), dtype=np.float32, minimum=tActionMin, maximum=tActionMax, name='action')
        self._observation_spec = array_spec.BoundedArraySpec(
            shape=(self.noObs,), dtype=np.float32, minimum=tObsMin, maximum=tObsMax, name='observation')
        self._state = 0
        self._episode_ended = False

    def action_spec(self):
        return self._action_spec

    def observation_spec(self):
        return self._observation_spec

    def _reset(self):
        self._state = 0
        self._episode_ended = False
        self.sample_stamp = 0
        self.track_distance = 0
        self.max_distance = 0
        self.action_history = []
        self.observation_history = []
        self.reward_accumulate = 0
        return ts.restart(np.array([0.0] * self.noObs, dtype=np.float32))

    def _step(self, action):
        #sample_period=0.1
        self.action_history.append(action)

        px4_update_pid_controller_all(action)
        #print("Action:", action)
        if self.sample_stamp == 0:
            self.sample_stamp = time.time()

        #wait for sample period
        while time.time() - self.sample_stamp < self.action_period:
            time.sleep(self.delay_period)
        self.sample_stamp = time.time()
    
        px4_set_target_depth_local(-target_elevation)
        observation = px4_get_telemetry_data()
        self.observation_history.append(observation)

        position = px4_get_position_data()
        #print("Position:", self._state, position)
        distance = distance_target([position[0], position[1], position[2]])
        self.track_distance  += distance
        if self.max_distance < distance:
            self.max_distance = distance

        if self._episode_ended:
            return self.reset()

        self._state += 1
        if self._state > self.sample_size:
            self._episode_ended = True

        current_reward = 1/((0.1+self.track_distance)/self.sample_size)/(0.1+self.max_distance)
        self.reward_accumulate += current_reward

        if self._episode_ended == True:
            #reward = current_reward
            print("Distance: %.3f / Max distance: %.3f / Reward: %.3f, " % (self.track_distance/self.sample_size, self.max_distance, self.reward_accumulate))
            f=open("px4_rl_output"+str(self.sample_size)+".txt", 'a')
            f.write("%.3f\t%.3f\t%.3f\n" % (self.track_distance/self.sample_size, self.max_distance, self.reward_accumulate))
            f.close()
            #f=open("px4_rl_action"+str(self.sample_size)+".txt", 'w')
            #for items in self.action_history:
            #    for item in items:
            #        f.write("%.3f\t" % item)
            #    f.write("\n")
            #f.close()            
            #f=open("px4_rl_observation"+str(self.sample_size)+".txt", 'w')
            #for items in self.observation_history:
            #    for item in items:
            #        f.write("%.3f\t" % item)
            #    f.write("\n")
            #f.close()            
            return ts.termination(np.array(observation, dtype=np.float32), current_reward)
        else:
            return ts.transition(
                np.array(observation, dtype=np.float32), reward=current_reward, discount=1.0)

# %%
def compute_avg_return(environment, policy, num_episodes=10):
    total_return = 0.0
    for _ in range(num_episodes):

        time_step = environment.reset()
        episode_return = 0.0

        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
        total_return += episode_return

    avg_return = total_return / num_episodes
    return avg_return.numpy()[0]

def collect_episode(environment, policy, num_episodes):

    driver = py_driver.PyDriver(
        environment,
        py_tf_eager_policy.PyTFEagerPolicy(
        policy, use_tf_function=True),
        [rb_observer],
        max_episodes=num_episodes)
    initial_time_step = environment.reset()
    driver.run(initial_time_step)

# %%
print("-----Setup PX4----------")
########################################
master = mavutil.mavlink_connection('udpin:localhost:14540')
boot_time = time.time()
master.wait_heartbeat()
print("Heartbeat: (system %u component %u)" % (master.target_system, master.target_component))
########################################
px4_reset_pid_controller()
px4_arm()
px4_request_message()
px4_steady_state()
# Out:
# -----Setup PX4----------
# Heartbeat: (system 1 component 0)
# State: arm
# State: set_mode
# State: mode_wait
# Mode: flight_mode
# Mode: steady_state

# %%
#####################
print("-----Instantiate PID----------")
train_duration=60 #sec
evaluation_duration=120 #sec
train_no_sample=train_duration/period_action
eval_no_sample=evaluation_duration/period_action
train_py_env = PX4_RL_PID(train_no_sample, period_delay, period_action)
eval_py_env = PX4_RL_PID(eval_no_sample, period_delay, period_action)
num_iterations = 1000 # @param {type:"integer"}
collect_episodes_per_iteration = 2 # @param {type:"integer"}
replay_buffer_capacity = 5000 # @param {type:"integer"}
fc_layer_params = (200,400,200,100,50)
learning_rate = 1e-3 # @param {type:"number"}
log_interval = 5 # @param {type:"integer"}
num_eval_episodes = 31# @param {type:"integer"}
eval_interval = 50 # @param {type:"integer"}
checkpoint_interval = 10
returns = []

print("-----TF setup----------")
train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)
actor_net = actor_distribution_network.ActorDistributionNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=fc_layer_params)

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
train_step_counter = tf.compat.v1.train.get_or_create_global_step()

print("-----TF agent----------")
tf_agent = reinforce_agent.ReinforceAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    actor_network=actor_net,
    optimizer=optimizer,
    normalize_returns=True,
    #train_step_counter=global_step)
    train_step_counter=train_step_counter)

tf_agent.initialize()

eval_policy = tf_agent.policy
collect_policy = tf_agent.collect_policy

print("-----Reverve----------")
table_name = 'uniform_table'
replay_buffer_signature = tensor_spec.from_spec(
    tf_agent.collect_data_spec)
replay_buffer_signature = tensor_spec.add_outer_dim(
    replay_buffer_signature)
table = reverb.Table(
    table_name,
    max_size=replay_buffer_capacity,
    sampler=reverb.selectors.Uniform(),
    remover=reverb.selectors.Fifo(),
    rate_limiter=reverb.rate_limiters.MinSize(1),
    signature=replay_buffer_signature)

reverb_server = reverb.Server([table])

replay_buffer = reverb_replay_buffer.ReverbReplayBuffer(
    tf_agent.collect_data_spec,
    table_name=table_name,
    sequence_length=None,
    local_server=reverb_server)

rb_observer = reverb_utils.ReverbAddEpisodeObserver(
    replay_buffer.py_client,
    table_name,
    replay_buffer_capacity
)

# (Optional) Optimize by wrapping some of the code in a graph using TF function.
tf_agent.train = common.function(tf_agent.train)

# Reset the train step
tf_agent.train_step_counter.assign(0)

# Checkpoint saver
tempdir='.'
checkpoint_dir = os.path.join(tempdir, 'checkpoint')
train_checkpointer = common.Checkpointer(
    ckpt_dir=checkpoint_dir,
    max_to_keep=1,
    agent=tf_agent,
    policy=tf_agent.policy,
    replay_buffer=replay_buffer,
    global_step=train_step_counter
    )
# Out:
# -----Instantiate PID----------
# -----TF setup----------
# -----TF agent----------
# -----Reverve----------

# %%
print("-----Evaluate----------")
# Evaluate the agent's policy once before training.
os.system("rm px4_rl_output"+str(eval_no_sample)+".txt")
avg_return = compute_avg_return(eval_env, tf_agent.policy, num_eval_episodes)
os.system("mv px4_rl_output"+str(eval_no_sample)+".txt px4_rl_output"+str(eval_no_sample)+"_0.txt")
returns = [avg_return]
# Out:
# -----Evaluate----------
# Distance: 0.218 / Max distance: 0.663 / Reward: 94757.967,
# Distance: 0.292 / Max distance: 2.034 / Reward: 44934.967,
# Distance: 0.246 / Max distance: 0.783 / Reward: 88584.083,
# Distance: 0.201 / Max distance: 0.766 / Reward: 81384.674,
# Distance: 0.264 / Max distance: 1.232 / Reward: 154254.284,
# Distance: 0.255 / Max distance: 0.822 / Reward: 67052.728,
# Distance: 0.271 / Max distance: 0.784 / Reward: 44109.644,
# Distance: 0.224 / Max distance: 1.022 / Reward: 104478.215,
# Distance: 0.233 / Max distance: 0.908 / Reward: 115263.050,
# Distance: 0.267 / Max distance: 0.834 / Reward: 303020.220,
# Distance: 0.284 / Max distance: 0.926 / Reward: 30347.675,
# Distance: 0.253 / Max distance: 0.712 / Reward: 40385.459,
# Distance: 0.257 / Max distance: 1.058 / Reward: 84747.432,
# Distance: 0.222 / Max distance: 0.717 / Reward: 228927.489,
# Distance: 0.243 / Max distance: 0.790 / Reward: 71358.512,
# Distance: 0.291 / Max distance: 1.283 / Reward: 106826.415,
# Distance: 0.264 / Max distance: 0.937 / Reward: 80490.169,
# Distance: 0.274 / Max distance: 1.071 / Reward: 83590.232,
# Distance: 0.249 / Max distance: 1.126 / Reward: 64205.109,
# Distance: 0.249 / Max distance: 1.154 / Reward: 53838.962,
# Distance: 0.284 / Max distance: 0.870 / Reward: 150200.651,
# Distance: 0.291 / Max distance: 1.463 / Reward: 91873.783,
# Distance: 0.244 / Max distance: 0.665 / Reward: 185613.257,
# Distance: 0.255 / Max distance: 1.456 / Reward: 113377.695,
# Distance: 0.255 / Max distance: 0.843 / Reward: 199859.925,
# Distance: 0.240 / Max distance: 0.794 / Reward: 68560.353,
# Distance: 0.269 / Max distance: 2.725 / Reward: 140133.504,
# Distance: 0.271 / Max distance: 1.091 / Reward: 35733.797,
# Distance: 0.256 / Max distance: 1.591 / Reward: 98819.667,
# Distance: 0.283 / Max distance: 1.856 / Reward: 147364.924,
# Distance: 0.280 / Max distance: 1.649 / Reward: 32281.261,

# %%
train_checkpointer.initialize_or_restore()
train_step_counter = tf.compat.v1.train.get_global_step()
print(train_step_counter)
# Out:
# <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=313>

# %%
print(train_step_counter)
# Out:
# <tf.Variable 'global_step:0' shape=() dtype=int64, numpy=3>

# %%
global_counter = int(tf.compat.v1.train.get_global_step())
print("-----Train----------")
############################################################
for _ in range(num_iterations):
    print("Iteration:", _, "/", global_counter)
    px4_arm()
    px4_reset_pid_controller()
    px4_steady_state()

    # Collect a few episodes using collect_policy and save to the replay buffer.
    collect_episode(
        train_py_env, tf_agent.collect_policy, collect_episodes_per_iteration)

    # Use data from the buffer and update the agent's network.
    iterator = iter(replay_buffer.as_dataset(sample_batch_size=1))
    trajectories, _ = next(iterator)
    train_loss = tf_agent.train(experience=trajectories)  

    replay_buffer.clear()

    step = tf_agent.train_step_counter.numpy()
    global_counter = int(tf.compat.v1.train.get_global_step())

    train_checkpointer.save(step)

    if step % log_interval == 0:
        print('step = {0}: loss = {1}'.format(step, train_loss.loss))
    
    if global_counter % checkpoint_interval == 0:
        os.system("cp -r checkpoint checkpoint_%d" % global_counter)  

    if global_counter % eval_interval == 0:
        os.system("rm px4_rl_output"+str(eval_no_sample)+".txt")
        avg_return = compute_avg_return(eval_env, tf_agent.policy, num_eval_episodes)
        os.system("mv px4_rl_output"+str(eval_no_sample)+".txt px4_rl_output"+str(eval_no_sample)+"_%d.txt" % global_counter)
        print('step = {0}: Average Return = {1}'.format(step, avg_return))
        returns.append(avg_return)
# Out:
# -----Train----------
# Iteration: 0 / 3
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.876 / Max distance: 4.676 / Reward: 17076.373,
# Distance: 0.413 / Max distance: 1.949 / Reward: 18650.888,
# Iteration: 1 / 4
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.316 / Max distance: 1.420 / Reward: 16754.309,
# Distance: 1.762 / Max distance: 9.007 / Reward: 28847.672,
# step = 5: loss = -51.7840690612793
# Iteration: 2 / 5
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.424 / Max distance: 2.443 / Reward: 34899.971,
# Distance: 0.762 / Max distance: 6.116 / Reward: 46578.873,
# Iteration: 3 / 6
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.347 / Max distance: 1.369 / Reward: 53593.439,
# Distance: 0.321 / Max distance: 1.133 / Reward: 17911.802,
# Iteration: 4 / 7
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.284 / Max distance: 0.816 / Reward: 70800.926,
# Distance: 0.402 / Max distance: 2.340 / Reward: 71133.002,
# Iteration: 5 / 8
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.398 / Max distance: 2.373 / Reward: 32315.201,
# Distance: 0.297 / Max distance: 0.988 / Reward: 80598.768,
# Iteration: 6 / 9
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.352 / Max distance: 1.462 / Reward: 53670.264,
# Distance: 0.583 / Max distance: 4.115 / Reward: 22412.609,
# step = 10: loss = 89.28860473632812
# Iteration: 7 / 10
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.500 / Max distance: 2.467 / Reward: 5878.294,
# Distance: 0.577 / Max distance: 4.521 / Reward: 18750.354,
# Iteration: 8 / 11
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.369 / Max distance: 3.994 / Reward: 21952.888,
# Distance: 0.376 / Max distance: 1.295 / Reward: 30032.160,
# Iteration: 9 / 12
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.355 / Max distance: 2.337 / Reward: 66611.128,
# Distance: 0.408 / Max distance: 3.108 / Reward: 23896.721,
# Iteration: 10 / 13
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.569 / Max distance: 4.386 / Reward: 30580.643,
# Distance: 0.448 / Max distance: 2.691 / Reward: 14470.952,
# Iteration: 11 / 14
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.368 / Max distance: 1.326 / Reward: 4182.043,
# Distance: 0.389 / Max distance: 2.653 / Reward: 25115.319,
# step = 15: loss = 17.646774291992188
# Iteration: 12 / 15
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.364 / Max distance: 1.122 / Reward: 13881.736,
# Distance: 0.412 / Max distance: 1.219 / Reward: 22498.642,
# Iteration: 13 / 16
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.590 / Max distance: 4.191 / Reward: 30748.867,
# Distance: 0.476 / Max distance: 1.435 / Reward: 20784.986,
# Iteration: 14 / 17
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.417 / Max distance: 2.489 / Reward: 30700.187,
# Distance: 0.412 / Max distance: 2.836 / Reward: 141605.407,
# Iteration: 15 / 18
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.909 / Max distance: 7.132 / Reward: 88348.939,
# Distance: 0.429 / Max distance: 2.723 / Reward: 23980.142,
# Iteration: 16 / 19
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.477 / Max distance: 2.240 / Reward: 13802.201,
# Distance: 0.333 / Max distance: 1.793 / Reward: 22752.638,
# step = 20: loss = 8.818252563476562
# Iteration: 17 / 20
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.441 / Max distance: 2.116 / Reward: 54782.697,
# Distance: 0.984 / Max distance: 6.521 / Reward: 36354.928,
# Iteration: 18 / 21
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.386 / Max distance: 1.192 / Reward: 17108.329,
# Distance: 1.705 / Max distance: 12.044 / Reward: 20957.813,
# Iteration: 19 / 22
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.455 / Max distance: 3.325 / Reward: 30414.217,
# Distance: 0.324 / Max distance: 1.401 / Reward: 22826.892,
# Iteration: 20 / 23
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.427 / Max distance: 2.591 / Reward: 30225.276,
# Distance: 0.498 / Max distance: 3.764 / Reward: 22641.017,
# Iteration: 21 / 24
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.257 / Max distance: 0.629 / Reward: 31035.346,
# Distance: 0.564 / Max distance: 4.384 / Reward: 15701.468,
# step = 25: loss = -93.52195739746094
# Iteration: 22 / 25
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.607 / Max distance: 4.680 / Reward: 41892.275,
# Distance: 1.143 / Max distance: 8.098 / Reward: 3483.100,
# Iteration: 23 / 26
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 3.010 / Max distance: 20.994 / Reward: 6519.850,
# Distance: 1.059 / Max distance: 9.188 / Reward: 142.971,
# Iteration: 24 / 27
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.308 / Max distance: 8.142 / Reward: 5369.559,
# Distance: 0.392 / Max distance: 1.612 / Reward: 9298.315,
# Iteration: 25 / 28
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.344 / Max distance: 0.999 / Reward: 7815.080,
# Distance: 0.899 / Max distance: 7.776 / Reward: 16436.782,
# Iteration: 26 / 29
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.357 / Max distance: 1.270 / Reward: 30866.634,
# Distance: 0.367 / Max distance: 1.216 / Reward: 16418.188,
# step = 30: loss = 64.74108123779297
# Iteration: 27 / 30
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.492 / Max distance: 3.340 / Reward: 38785.570,
# Distance: 0.344 / Max distance: 2.300 / Reward: 2279.039,
# Iteration: 28 / 31
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.669 / Max distance: 6.255 / Reward: 16089.055,
# Distance: 0.418 / Max distance: 1.970 / Reward: 43916.944,
# Iteration: 29 / 32
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.535 / Max distance: 2.820 / Reward: 22773.324,
# Distance: 0.692 / Max distance: 5.626 / Reward: 22159.033,
# Iteration: 30 / 33
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.608 / Max distance: 3.356 / Reward: 60530.670,
# Distance: 1.126 / Max distance: 6.650 / Reward: 79194.957,
# Iteration: 31 / 34
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.306 / Max distance: 1.039 / Reward: 18970.137,
# Distance: 0.447 / Max distance: 4.106 / Reward: 15524.005,
# step = 35: loss = 32.19696044921875
# Iteration: 32 / 35
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.362 / Max distance: 1.856 / Reward: 22114.594,
# Distance: 0.424 / Max distance: 4.174 / Reward: 39747.185,
# Iteration: 33 / 36
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.379 / Max distance: 1.837 / Reward: 47780.000,
# Distance: 0.484 / Max distance: 2.609 / Reward: 3871.435,
# Iteration: 34 / 37
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.796 / Max distance: 4.444 / Reward: 27872.669,
# Distance: 1.595 / Max distance: 11.847 / Reward: 28998.722,
# Iteration: 35 / 38
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.497 / Max distance: 2.647 / Reward: 13894.058,
# Distance: 0.335 / Max distance: 1.281 / Reward: 15519.732,
# Iteration: 36 / 39
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 2.283 / Max distance: 12.510 / Reward: 4662.708,
# Distance: 0.442 / Max distance: 2.122 / Reward: 21566.869,
# step = 40: loss = -67.72581481933594
# Iteration: 37 / 40
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.456 / Max distance: 1.779 / Reward: 22476.322,
# Distance: 0.473 / Max distance: 4.152 / Reward: 25776.164,
# Iteration: 38 / 41
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.529 / Max distance: 3.743 / Reward: 68043.212,
# Distance: 1.676 / Max distance: 13.342 / Reward: 4070.388,
# Iteration: 39 / 42
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.438 / Max distance: 3.485 / Reward: 25596.250,
# Distance: 0.506 / Max distance: 3.541 / Reward: 1212.374,
# Iteration: 40 / 43
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 1.302 / Max distance: 8.758 / Reward: 21877.923,
# Distance: 0.306 / Max distance: 1.131 / Reward: 32585.675,
# Iteration: 41 / 44
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.447 / Max distance: 2.849 / Reward: 8024.245,
# Distance: 0.693 / Max distance: 3.825 / Reward: 27415.541,
# step = 45: loss = -39.918174743652344
# Iteration: 42 / 45
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.395 / Max distance: 1.432 / Reward: 30930.758,
# Distance: 0.349 / Max distance: 1.998 / Reward: 22486.803,
# Iteration: 43 / 46
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.360 / Max distance: 1.643 / Reward: 34495.801,
# Distance: 0.544 / Max distance: 4.022 / Reward: 28758.243,
# Iteration: 44 / 47
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.302 / Max distance: 0.873 / Reward: 31928.631,
# Distance: 0.520 / Max distance: 4.168 / Reward: 14901.556,
# Iteration: 45 / 48
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.535 / Max distance: 4.320 / Reward: 26753.964,
# Distance: 0.571 / Max distance: 4.285 / Reward: 40613.452,
# Iteration: 46 / 49
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.215 / Max distance: 8.850 / Reward: 42376.181,
# Distance: 2.977 / Max distance: 21.705 / Reward: 33092.639,
# step = 50: loss = 213.97732543945312
# Distance: 0.249 / Max distance: 0.957 / Reward: 33295.377,
# Distance: 0.222 / Max distance: 0.673 / Reward: 83779.763,
# Distance: 0.232 / Max distance: 0.869 / Reward: 42645.177,
# Distance: 0.254 / Max distance: 0.979 / Reward: 25841.736,
# Distance: 0.249 / Max distance: 1.035 / Reward: 80647.840,
# Distance: 0.263 / Max distance: 0.756 / Reward: 66390.165,
# Distance: 0.250 / Max distance: 0.827 / Reward: 168882.821,
# Distance: 0.243 / Max distance: 0.762 / Reward: 89267.395,
# Distance: 0.278 / Max distance: 1.790 / Reward: 149344.360,
# Distance: 0.234 / Max distance: 0.955 / Reward: 40653.949,
# Distance: 0.256 / Max distance: 0.698 / Reward: 61231.901,
# Distance: 0.271 / Max distance: 0.835 / Reward: 51378.747,
# Distance: 0.302 / Max distance: 1.595 / Reward: 129973.494,
# Distance: 0.269 / Max distance: 0.711 / Reward: 122280.814,
# Distance: 0.252 / Max distance: 0.980 / Reward: 28787.511,
# Distance: 0.250 / Max distance: 0.594 / Reward: 52247.287,
# Distance: 0.255 / Max distance: 1.175 / Reward: 48416.747,
# Distance: 0.234 / Max distance: 0.672 / Reward: 52993.183,
# Distance: 0.301 / Max distance: 1.492 / Reward: 114333.072,
# Distance: 0.259 / Max distance: 1.049 / Reward: 218002.453,
# Distance: 0.274 / Max distance: 1.616 / Reward: 98491.656,
# Distance: 0.248 / Max distance: 1.367 / Reward: 47329.641,
# Distance: 0.245 / Max distance: 0.780 / Reward: 82007.526,
# Distance: 0.274 / Max distance: 0.712 / Reward: 40688.188,
# Distance: 0.238 / Max distance: 1.106 / Reward: 68746.219,
# Distance: 0.241 / Max distance: 0.863 / Reward: 72875.172,
# Distance: 0.235 / Max distance: 0.978 / Reward: 68084.466,
# Distance: 0.295 / Max distance: 1.186 / Reward: 142247.257,
# Distance: 0.260 / Max distance: 1.381 / Reward: 102170.985,
# Distance: 0.286 / Max distance: 1.145 / Reward: 191573.717,
# Distance: 0.251 / Max distance: 1.395 / Reward: 144737.297,
# step = 50: Average Return = 87720.8359375
# Iteration: 47 / 50
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.693 / Max distance: 4.639 / Reward: 40035.439,
# Distance: 0.411 / Max distance: 2.126 / Reward: 12448.311,
# Iteration: 48 / 51
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.379 / Max distance: 2.769 / Reward: 47618.319,
# Distance: 0.443 / Max distance: 2.458 / Reward: 18299.077,
# Iteration: 49 / 52
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.459 / Max distance: 1.989 / Reward: 4578.537,
# Distance: 0.262 / Max distance: 0.729 / Reward: 23841.612,
# Iteration: 50 / 53
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.606 / Max distance: 4.472 / Reward: 39200.934,
# Distance: 0.658 / Max distance: 5.669 / Reward: 7441.668,
# Iteration: 51 / 54
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.340 / Max distance: 1.606 / Reward: 6493.188,
# Distance: 1.027 / Max distance: 6.274 / Reward: 35011.724,
# step = 55: loss = -68.07628631591797
# Iteration: 52 / 55
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.318 / Max distance: 2.152 / Reward: 28782.464,
# Distance: 0.850 / Max distance: 6.540 / Reward: 13339.408,
# Iteration: 53 / 56
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.587 / Max distance: 3.684 / Reward: 23007.263,
# Distance: 0.295 / Max distance: 1.349 / Reward: 21777.277,
# Iteration: 54 / 57
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.354 / Max distance: 1.113 / Reward: 40964.324,
# Distance: 0.364 / Max distance: 1.772 / Reward: 21785.824,
# Iteration: 55 / 58
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.667 / Max distance: 5.166 / Reward: 37013.722,
# Distance: 0.466 / Max distance: 3.039 / Reward: 12377.700,
# Iteration: 56 / 59
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.562 / Max distance: 3.365 / Reward: 19023.034,
# Distance: 0.563 / Max distance: 3.753 / Reward: 3986.598,
# step = 60: loss = -19.811233520507812
# Iteration: 57 / 60
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.453 / Max distance: 2.736 / Reward: 43563.310,
# Distance: 0.364 / Max distance: 1.079 / Reward: 14231.119,
# Iteration: 58 / 61
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.679 / Max distance: 5.955 / Reward: 23030.034,
# Distance: 0.887 / Max distance: 5.752 / Reward: 39839.182,
# Iteration: 59 / 62
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.383 / Max distance: 1.515 / Reward: 24045.006,
# Distance: 0.525 / Max distance: 3.294 / Reward: 14058.680,
# Iteration: 60 / 63
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.369 / Max distance: 1.832 / Reward: 15359.194,
# Distance: 0.381 / Max distance: 2.451 / Reward: 28046.472,
# Iteration: 61 / 64
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.292 / Max distance: 0.882 / Reward: 43048.315,
# Distance: 0.743 / Max distance: 7.081 / Reward: 67752.463,
# step = 65: loss = -77.74943542480469
# Iteration: 62 / 65
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.325 / Max distance: 1.124 / Reward: 45502.523,
# Distance: 0.442 / Max distance: 2.650 / Reward: 96395.747,
# Iteration: 63 / 66
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.223 / Max distance: 13.297 / Reward: 23958.454,
# Distance: 1.058 / Max distance: 9.183 / Reward: 32846.987,
# Iteration: 64 / 67
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.362 / Max distance: 3.554 / Reward: 3562.336,
# Distance: 2.093 / Max distance: 14.737 / Reward: 149.111,
# Iteration: 65 / 68
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 1.000 / Max distance: 8.232 / Reward: 22659.056,
# Distance: 0.347 / Max distance: 2.261 / Reward: 9843.717,
# Iteration: 66 / 69
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.318 / Max distance: 1.163 / Reward: 28296.912,
# Distance: 0.787 / Max distance: 5.342 / Reward: 29786.594,
# step = 70: loss = 5.5667572021484375
# Iteration: 67 / 70
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.373 / Max distance: 1.457 / Reward: 37599.874,
# Distance: 0.418 / Max distance: 2.024 / Reward: 113798.707,
# Iteration: 68 / 71
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.430 / Max distance: 10.222 / Reward: 43275.467,
# Distance: 0.549 / Max distance: 3.166 / Reward: 10855.978,
# Iteration: 69 / 72
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.308 / Max distance: 1.860 / Reward: 80688.087,
# Distance: 0.924 / Max distance: 4.590 / Reward: 43298.655,
# Iteration: 70 / 73
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.966 / Max distance: 14.278 / Reward: 30720.389,
# Distance: 1.207 / Max distance: 8.219 / Reward: 19558.053,
# Iteration: 71 / 74
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.407 / Max distance: 2.878 / Reward: 21931.391,
# Distance: 0.966 / Max distance: 6.525 / Reward: 14646.824,
# step = 75: loss = -30.722747802734375
# Iteration: 72 / 75
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.439 / Max distance: 3.086 / Reward: 40895.370,
# Distance: 0.289 / Max distance: 1.105 / Reward: 65192.447,
# Iteration: 73 / 76
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.403 / Max distance: 1.440 / Reward: 6520.690,
# Distance: 0.282 / Max distance: 1.130 / Reward: 79590.987,
# Iteration: 74 / 77
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.305 / Max distance: 0.722 / Reward: 38990.951,
# Distance: 0.304 / Max distance: 1.649 / Reward: 35206.429,
# Iteration: 75 / 78
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.388 / Max distance: 2.772 / Reward: 3947.688,
# Distance: 0.286 / Max distance: 0.923 / Reward: 23716.434,
# Iteration: 76 / 79
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.282 / Max distance: 1.108 / Reward: 37670.465,
# Distance: 0.332 / Max distance: 2.389 / Reward: 24596.596,
# step = 80: loss = -8.294013977050781
# Iteration: 77 / 80
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.602 / Max distance: 2.766 / Reward: 36175.335,
# Distance: 0.412 / Max distance: 2.310 / Reward: 45159.710,
# Iteration: 78 / 81
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.308 / Max distance: 1.353 / Reward: 28901.821,
# Distance: 0.502 / Max distance: 3.896 / Reward: 15467.118,
# Iteration: 79 / 82
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.390 / Max distance: 3.206 / Reward: 49310.880,
# Distance: 0.289 / Max distance: 1.370 / Reward: 13908.036,
# Iteration: 80 / 83
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.290 / Max distance: 0.859 / Reward: 35931.589,
# Distance: 0.344 / Max distance: 2.031 / Reward: 19057.461,
# Iteration: 81 / 84
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.251 / Max distance: 0.841 / Reward: 42730.339,
# Distance: 0.288 / Max distance: 1.500 / Reward: 41308.235,
# step = 85: loss = -30.74225616455078
# Iteration: 82 / 85
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.270 / Max distance: 0.866 / Reward: 57510.131,
# Distance: 0.416 / Max distance: 2.397 / Reward: 21418.127,
# Iteration: 83 / 86
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.311 / Max distance: 1.503 / Reward: 19646.490,
# Distance: 0.379 / Max distance: 2.452 / Reward: 19224.911,
# Iteration: 84 / 87
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.244 / Max distance: 0.789 / Reward: 60136.392,
# Distance: 0.311 / Max distance: 0.932 / Reward: 12311.202,
# Iteration: 85 / 88
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.313 / Max distance: 0.854 / Reward: 22630.436,
# Distance: 0.239 / Max distance: 0.643 / Reward: 25188.715,
# Iteration: 86 / 89
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.458 / Max distance: 3.023 / Reward: 42204.665,
# Distance: 0.504 / Max distance: 2.114 / Reward: 3943.041,
# step = 90: loss = 0.10401153564453125
# Iteration: 87 / 90
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.335 / Max distance: 1.339 / Reward: 14156.276,
# Distance: 0.295 / Max distance: 1.369 / Reward: 4708.024,
# Iteration: 88 / 91
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.257 / Max distance: 1.122 / Reward: 45578.430,
# Distance: 0.245 / Max distance: 0.624 / Reward: 105834.663,
# Iteration: 89 / 92
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.326 / Max distance: 1.422 / Reward: 66044.699,
# Distance: 0.324 / Max distance: 1.222 / Reward: 70138.928,
# Iteration: 90 / 93
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.255 / Max distance: 0.849 / Reward: 27450.120,
# Distance: 0.258 / Max distance: 0.646 / Reward: 44165.195,
# Iteration: 91 / 94
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.319 / Max distance: 1.290 / Reward: 52652.771,
# Distance: 0.348 / Max distance: 2.335 / Reward: 8852.021,
# step = 95: loss = -202.11923217773438
# Iteration: 92 / 95
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.296 / Max distance: 1.288 / Reward: 65322.648,
# Distance: 0.298 / Max distance: 0.719 / Reward: 37621.786,
# Iteration: 93 / 96
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.540 / Max distance: 3.724 / Reward: 20735.658,
# Distance: 0.482 / Max distance: 2.551 / Reward: 10644.836,
# Iteration: 94 / 97
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.333 / Max distance: 1.262 / Reward: 29932.957,
# Distance: 0.566 / Max distance: 4.245 / Reward: 10181.147,
# Iteration: 95 / 98
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.288 / Max distance: 1.176 / Reward: 49575.071,
# Distance: 0.372 / Max distance: 2.237 / Reward: 43094.302,
# Iteration: 96 / 99
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.309 / Max distance: 1.013 / Reward: 60373.610,
# Distance: 0.258 / Max distance: 0.774 / Reward: 24266.727,
# step = 100: loss = -63.59947204589844
# Distance: 0.242 / Max distance: 1.070 / Reward: 49822.197,
# Distance: 0.230 / Max distance: 1.286 / Reward: 83548.595,
# Distance: 0.225 / Max distance: 0.772 / Reward: 53474.537,
# Distance: 0.220 / Max distance: 0.775 / Reward: 49313.752,
# Distance: 0.234 / Max distance: 0.987 / Reward: 59720.074,
# Distance: 0.300 / Max distance: 2.492 / Reward: 22021.774,
# Distance: 0.253 / Max distance: 0.896 / Reward: 122715.670,
# Distance: 0.233 / Max distance: 0.730 / Reward: 77411.184,
# Distance: 0.226 / Max distance: 0.814 / Reward: 75691.054,
# Distance: 0.292 / Max distance: 2.157 / Reward: 61242.899,
# Distance: 0.233 / Max distance: 0.665 / Reward: 105745.593,
# Distance: 0.243 / Max distance: 1.302 / Reward: 66616.576,
# Distance: 0.232 / Max distance: 1.000 / Reward: 74684.728,
# Distance: 0.241 / Max distance: 1.015 / Reward: 20521.393,
# Distance: 0.274 / Max distance: 0.980 / Reward: 36387.960,
# Distance: 0.229 / Max distance: 0.663 / Reward: 78528.008,
# Distance: 0.226 / Max distance: 0.816 / Reward: 170725.012,
# Distance: 0.232 / Max distance: 0.739 / Reward: 192885.813,
# Distance: 0.250 / Max distance: 0.729 / Reward: 74010.869,
# Distance: 0.256 / Max distance: 1.153 / Reward: 44684.996,
# Distance: 0.263 / Max distance: 1.202 / Reward: 47760.497,
# Distance: 0.240 / Max distance: 1.127 / Reward: 19429.774,
# Distance: 0.230 / Max distance: 0.859 / Reward: 63584.812,
# Distance: 0.225 / Max distance: 0.622 / Reward: 142491.070,
# Distance: 0.280 / Max distance: 1.558 / Reward: 42779.161,
# Distance: 0.237 / Max distance: 0.918 / Reward: 107007.896,
# Distance: 0.223 / Max distance: 0.808 / Reward: 141433.955,
# Distance: 0.245 / Max distance: 1.145 / Reward: 76018.025,
# Distance: 0.246 / Max distance: 1.209 / Reward: 56219.968,
# Distance: 0.244 / Max distance: 1.022 / Reward: 113016.408,
# Distance: 0.254 / Max distance: 1.063 / Reward: 87567.978,
# step = 100: Average Return = 77969.734375
# Iteration: 97 / 100
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.442 / Max distance: 2.997 / Reward: 20339.847,
# Distance: 0.348 / Max distance: 1.672 / Reward: 48187.982,
# Iteration: 98 / 101
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.309 / Max distance: 1.596 / Reward: 26152.586,
# Distance: 0.326 / Max distance: 1.489 / Reward: 66267.346,
# Iteration: 99 / 102
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.343 / Max distance: 1.500 / Reward: 22091.385,
# Distance: 0.627 / Max distance: 5.376 / Reward: 49210.701,
# Iteration: 100 / 103
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.482 / Max distance: 3.058 / Reward: 45905.866,
# Distance: 0.382 / Max distance: 2.079 / Reward: 29819.720,
# Iteration: 101 / 104
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.560 / Max distance: 3.657 / Reward: 66334.559,
# Distance: 0.380 / Max distance: 2.777 / Reward: 29995.303,
# step = 105: loss = -58.93919372558594
# Iteration: 102 / 105
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.497 / Max distance: 3.622 / Reward: 27317.026,
# Distance: 0.538 / Max distance: 4.094 / Reward: 601.183,
# Iteration: 103 / 106
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.395 / Max distance: 2.286 / Reward: 23036.704,
# Distance: 1.297 / Max distance: 10.085 / Reward: 15905.167,
# Iteration: 104 / 107
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.668 / Max distance: 4.607 / Reward: 28660.904,
# Distance: 0.401 / Max distance: 1.190 / Reward: 18155.154,
# Iteration: 105 / 108
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.559 / Max distance: 4.777 / Reward: 31356.352,
# Distance: 0.728 / Max distance: 5.225 / Reward: 29670.178,
# Iteration: 106 / 109
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.741 / Max distance: 4.765 / Reward: 42842.445,
# Distance: 0.364 / Max distance: 1.421 / Reward: 57856.771,
# step = 110: loss = -42.43738555908203
# Iteration: 107 / 110
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 1.731 / Max distance: 14.278 / Reward: 26826.685,
# Distance: 0.772 / Max distance: 11.493 / Reward: 104.027,
# Iteration: 108 / 111
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.034 / Max distance: 9.766 / Reward: 7445.603,
# Distance: 0.979 / Max distance: 6.793 / Reward: 26900.107,
# Iteration: 109 / 112
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.371 / Max distance: 1.490 / Reward: 46526.904,
# Distance: 0.504 / Max distance: 2.211 / Reward: 22086.558,
# Iteration: 110 / 113
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.851 / Max distance: 4.787 / Reward: 15429.853,
# Distance: 0.846 / Max distance: 8.453 / Reward: 21263.396,
# Iteration: 111 / 114
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 1.464 / Max distance: 7.866 / Reward: 32763.770,
# Distance: 0.991 / Max distance: 8.658 / Reward: 26218.768,
# step = 115: loss = -0.43103790283203125
# Iteration: 112 / 115
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.486 / Max distance: 2.662 / Reward: 22266.605,
# Distance: 0.321 / Max distance: 2.226 / Reward: 21585.685,
# Iteration: 113 / 116
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.442 / Max distance: 3.014 / Reward: 42085.320,
# Distance: 0.318 / Max distance: 1.258 / Reward: 22204.931,
# Iteration: 114 / 117
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.765 / Max distance: 7.025 / Reward: 9288.331,
# Distance: 0.415 / Max distance: 2.029 / Reward: 9387.047,
# Iteration: 115 / 118
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.656 / Max distance: 3.796 / Reward: 35981.958,
# Distance: 0.607 / Max distance: 4.368 / Reward: 12867.405,
# Iteration: 116 / 119
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.688 / Max distance: 9.535 / Reward: 6956.205,
# Distance: 0.635 / Max distance: 3.442 / Reward: 976.864,
# step = 120: loss = 30.360153198242188
# Iteration: 117 / 120
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.636 / Max distance: 3.808 / Reward: 29074.175,
# Distance: 0.530 / Max distance: 3.403 / Reward: 16782.175,
# Iteration: 118 / 121
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.630 / Max distance: 3.745 / Reward: 70848.131,
# Distance: 0.386 / Max distance: 2.708 / Reward: 18825.335,
# Iteration: 119 / 122
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.560 / Max distance: 3.927 / Reward: 134285.497,
# Distance: 1.244 / Max distance: 4.842 / Reward: 21652.711,
# Iteration: 120 / 123
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.389 / Max distance: 2.312 / Reward: 58407.600,
# Distance: 0.411 / Max distance: 1.887 / Reward: 44952.191,
# Iteration: 121 / 124
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.541 / Max distance: 3.993 / Reward: 22376.746,
# Distance: 0.983 / Max distance: 8.843 / Reward: 23682.277,
# step = 125: loss = 17.159271240234375
# Iteration: 122 / 125
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.374 / Max distance: 1.502 / Reward: 37821.501,
# Distance: 0.347 / Max distance: 1.725 / Reward: 26113.424,
# Iteration: 123 / 126
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.637 / Max distance: 4.044 / Reward: 24313.967,
# Distance: 0.506 / Max distance: 3.515 / Reward: 34052.541,
# Iteration: 124 / 127
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.746 / Max distance: 10.343 / Reward: 34482.045,
# Distance: 0.947 / Max distance: 11.820 / Reward: 82.115,
# Iteration: 125 / 128
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.464 / Max distance: 2.594 / Reward: 40549.743,
# Distance: 0.310 / Max distance: 1.061 / Reward: 31575.839,
# Iteration: 126 / 129
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.358 / Max distance: 1.673 / Reward: 38692.301,
# Distance: 0.883 / Max distance: 4.979 / Reward: 7051.498,
# step = 130: loss = -67.21068572998047
# Iteration: 127 / 130
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.652 / Max distance: 5.417 / Reward: 26700.380,
# Distance: 1.255 / Max distance: 10.923 / Reward: 3603.861,
# Iteration: 128 / 131
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.597 / Max distance: 4.146 / Reward: 21502.279,
# Distance: 0.345 / Max distance: 1.601 / Reward: 35996.819,
# Iteration: 129 / 132
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.520 / Max distance: 4.220 / Reward: 5931.195,
# Distance: 0.396 / Max distance: 1.306 / Reward: 34653.715,
# Iteration: 130 / 133
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.814 / Max distance: 7.183 / Reward: 50702.505,
# Distance: 0.608 / Max distance: 4.026 / Reward: 2290.736,
# Iteration: 131 / 134
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.512 / Max distance: 4.213 / Reward: 33325.173,
# Distance: 0.484 / Max distance: 4.021 / Reward: 689.434,
# step = 135: loss = -26.226776123046875
# Iteration: 132 / 135
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.645 / Max distance: 4.524 / Reward: 23157.842,
# Distance: 0.664 / Max distance: 5.250 / Reward: 5390.263,
# Iteration: 133 / 136
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.551 / Max distance: 2.885 / Reward: 21491.478,
# Distance: 0.853 / Max distance: 5.802 / Reward: 20261.734,
# Iteration: 134 / 137
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 1.430 / Max distance: 11.930 / Reward: 7398.440,
# Distance: 1.101 / Max distance: 9.707 / Reward: 35797.020,
# Iteration: 135 / 138
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 0.604 / Max distance: 2.673 / Reward: 21240.514,
# Distance: 0.314 / Max distance: 1.688 / Reward: 82528.803,
# Iteration: 136 / 139
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.943 / Max distance: 5.686 / Reward: 20055.070,
# Distance: 0.793 / Max distance: 8.837 / Reward: 19224.269,
# step = 140: loss = 8.492485046386719
# Iteration: 137 / 140
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.408 / Max distance: 3.122 / Reward: 44861.692,
# Distance: 1.610 / Max distance: 7.465 / Reward: 9332.263,
# Iteration: 138 / 141
# State: arm
# State: set_mode
# Mode: flight_mode
# State: mode_wait
# Mode: steady_state
# Distance: 0.330 / Max distance: 1.858 / Reward: 40220.773,
# Distance: 0.363 / Max distance: 1.227 / Reward: 57810.919,
# Iteration: 139 / 142
# State: arm
# State: set_mode
# Mode: flight_mode
# Mode: steady_state
# Distance: 1.103 / Max distance: 8.933 / Reward: 40174.142,

# %%
print("-----Evaluate----------")
# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, tf_agent.policy, 31)
print(avg_return)
# Out:
# -----Evaluate----------
# Distance: 0.77 / Max distance: 8.33 / Reward: 4825.216,
# Distance: 1.62 / Max distance: 11.72 / Reward: 58024.958,
# Distance: 1.04 / Max distance: 10.48 / Reward: 3436.741,
# Distance: 0.29 / Max distance: 1.90 / Reward: 65314.151,
# Distance: 1.02 / Max distance: 10.13 / Reward: 7737.911,
# Distance: 0.31 / Max distance: 3.75 / Reward: 15959.703,
# Distance: 0.57 / Max distance: 8.95 / Reward: 106630.083,
# Distance: 0.73 / Max distance: 13.00 / Reward: 20077.833,
# Distance: 0.22 / Max distance: 0.74 / Reward: 66972.202,
# Distance: 0.65 / Max distance: 9.50 / Reward: 29658.820,
# Distance: 0.73 / Max distance: 7.06 / Reward: 36020.995,
# Distance: 0.46 / Max distance: 6.41 / Reward: 193066.732,
# Distance: 1.31 / Max distance: 9.66 / Reward: 78800.997,
# Distance: 0.33 / Max distance: 3.17 / Reward: 190790.397,
# Distance: 1.10 / Max distance: 12.42 / Reward: 1009.403,
# Distance: 1.08 / Max distance: 6.28 / Reward: 12085.598,
# Distance: 0.26 / Max distance: 0.96 / Reward: 226255.309,
# Distance: 0.31 / Max distance: 1.50 / Reward: 41151.386,
# Distance: 0.57 / Max distance: 6.25 / Reward: 72612.660,
# Distance: 0.47 / Max distance: 4.93 / Reward: 69188.652,
# Distance: 0.27 / Max distance: 1.66 / Reward: 123244.314,
# Distance: 0.31 / Max distance: 2.83 / Reward: 216135.973,
# Distance: 0.30 / Max distance: 2.45 / Reward: 93190.316,
# Distance: 0.43 / Max distance: 2.95 / Reward: 44469.379,
# Distance: 0.46 / Max distance: 7.35 / Reward: 73595.861,
# Distance: 0.44 / Max distance: 6.23 / Reward: 97463.359,
# Distance: 0.56 / Max distance: 4.65 / Reward: 57111.273,
# Distance: 0.40 / Max distance: 4.85 / Reward: 53189.737,
# Distance: 0.30 / Max distance: 1.20 / Reward: 84011.239,
# Distance: 0.40 / Max distance: 3.43 / Reward: 64648.294,
# Distance: 0.33 / Max distance: 3.44 / Reward: 114877.513,
# 74888.92
